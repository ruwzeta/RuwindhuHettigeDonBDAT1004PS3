# %% [markdown]
# # Problem Set 3 - 200490726 - Hettige Don Ruwindhu Chandraratne

# %% [markdown]
# ### Question 1
# ### Occupations
# Introduction:
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.

# %%
## Step 1. Import the necessary libraries
import pandas as pd 
import numpy as np

# %%
## Step 2. Import the dataset from this address.
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep= '|')
## Step 3.Assign it to a variable called users
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
## Step 4. Discover what is the mean age per occupation
mean_age = users.groupby(users['occupation'])['age'].aggregate('mean')
mean_age
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
## Step 5. Discover the Male ratio per occupation and sort it from the most to the least
group_by_occupations = users[['occupation','gender']].groupby('occupation').count()
group_by_occupations
# Out:
#                gender
# occupation
# administrator      79
# artist             28
# doctor              7
# educator           95
# engineer           67
# entertainment      18
# executive          32
# healthcare         16
# homemaker           7
# lawyer             12
# librarian          51
# marketing          26
# none                9
# other             105
# programmer         66
# retired            14
# salesman           12
# scientist          31
# student           196
# technician         27
# writer             45

# %%
males_occupations = users.loc[users['gender'] == 'M'][['gender','occupation']]

males_group_by_occupations = males_occupations.groupby('occupation').count()

males_group_by_occupations
# Out:
#                gender
# occupation
# administrator      43
# artist             15
# doctor              7
# educator           69
# engineer           65
# entertainment      16
# executive          29
# healthcare          5
# homemaker           1
# lawyer             10
# librarian          22
# marketing          16
# none                5
# other              69
# programmer         60
# retired            13
# salesman            9
# scientist          28
# student           136
# technician         26
# writer             26

# %%
males_ratio =  males_group_by_occupations / group_by_occupations

males_ratio.sort_values(ascending= False, by = 'gender')
# Out:
#                  gender
# occupation
# doctor         1.000000
# engineer       0.970149
# technician     0.962963
# retired        0.928571
# programmer     0.909091
# executive      0.906250
# scientist      0.903226
# entertainment  0.888889
# lawyer         0.833333
# salesman       0.750000
# educator       0.726316
# student        0.693878
# other          0.657143
# marketing      0.615385
# writer         0.577778
# none           0.555556
# administrator  0.544304
# artist         0.535714
# librarian      0.431373
# healthcare     0.312500
# homemaker      0.142857

# %%
## Step 6. For each occupation, calculate the minimum and maximum ages

min_age_occupation = users.groupby(users['occupation'])['age'].aggregate('min')
min_age_occupation
# Out:
# occupation
# administrator    21
# artist           19
# doctor           28
# educator         23
# engineer         22
# entertainment    15
# executive        22
# healthcare       22
# homemaker        20
# lawyer           21
# librarian        23
# marketing        24
# none             11
# other            13
# programmer       20
# retired          51
# salesman         18
# scientist        23
# student           7
# technician       21
# writer           18
# Name: age, dtype: int64

# %%
max_age_occupation = users.groupby(users['occupation'])['age'].aggregate('max')
max_age_occupation
# Out:
# occupation
# administrator    70
# artist           48
# doctor           64
# educator         63
# engineer         70
# entertainment    50
# executive        69
# healthcare       62
# homemaker        50
# lawyer           53
# librarian        69
# marketing        55
# none             55
# other            64
# programmer       63
# retired          73
# salesman         66
# scientist        55
# student          42
# technician       55
# writer           60
# Name: age, dtype: int64

# %%
# Step 7. For each combination of occupation and sex, calculate the mean age
mean_age_occ_sex = users.groupby(['occupation','gender'])['age'].aggregate('mean')
mean_age_occ_sex
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
#Step 8. For each occupation present the percentage of women and men

total_counts = users.groupby(['occupation'])['zip_code'].aggregate('count')
occupation_counts = users.groupby(['occupation','gender'])['zip_code'].aggregate('count')
occupation_percent = round((occupation_counts / total_counts) *100,2)
occupation_percent
# Out:
# occupation     gender
# administrator  F          45.57
#                M          54.43
# artist         F          46.43
#                M          53.57
# doctor         M         100.00
# educator       F          27.37
#                M          72.63
# engineer       F           2.99
#                M          97.01
# entertainment  F          11.11
#                M          88.89
# executive      F           9.38
#                M          90.62
# healthcare     F          68.75
#                M          31.25
# homemaker      F          85.71
#                M          14.29
# lawyer         F          16.67
#                M          83.33
# librarian      F          56.86
#                M          43.14
# marketing      F          38.46
#                M          61.54
# none           F          44.44
#                M          55.56
# other          F          34.29
#                M          65.71
# programmer     F           9.09
# ...

# %% [markdown]
# ### Question 2
#
# ### Euro Teams

# %%
#Step 1. Import the necessary libraries 
import pandas as pd 
import numpy as np

# %%
# Step 2. Import the dataset from this address
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')
# Step 3. Assign it to a variable called euro12
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Step 4. Select only the Goal column
goal_col = euro12['Goals']
goal_col
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#Step 5. How many team participated in the Euro2012?
unique_teams = euro12['Team'].nunique()
unique_teams
# Out:
# 16

# %%
#Step 6. What is the number of columns in the dataset?
cols = len(euro12.axes[1])
cols
# Out:
# 35

# %%
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
discipline = euro12[['Team','Yellow Cards','Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# Step 8. Sort the teams by Red Cards, then to Yellow Cards
discipline_sorted = discipline.sort_values(['Red Cards','Yellow Cards'], ascending= False)
discipline_sorted
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
# Step 9. Calculate the mean Yellow Cards given per Team
discipline_mean_yellow_cards = discipline['Yellow Cards'].mean()
discipline_mean_yellow_cards
# Out:
# 7.4375

# %%
# Step 10. Filter teams that scored more than 6 goals
filter_more_6_goals = euro12[euro12['Goals'] > 6 ]['Team']
filter_more_6_goals
# Out:
# 5     Germany
# 13      Spain
# Name: Team, dtype: object

# %%
# Step 11. Select the teams that start with G
teams_with_G = euro12[euro12['Team'].str.startswith('G')]['Team']
teams_with_G
# Out:
# 5    Germany
# 6     Greece
# Name: Team, dtype: object

# %%
# Step 12. Select the first 7 columns
first_7_cols = euro12.iloc[:,:7]
first_7_cols
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Step 13. Select all columns except the last 3
no_last3_cols = euro12.iloc[:,:-3]
no_last3_cols
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia
shooting_accur = euro12.loc[euro12['Team'].isin(['England','Italy','Russia'])][['Team','Shooting Accuracy']]
shooting_accur
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# ### Question 3
#
#
# ### Housing

# %%
# Step 1. Import the necessary libraries
import pandas as pd
import numpy as np

# %%
# Step 2. Create 3 differents Series, each of length 100, as follows:
# • The first a random number from 1 to 4
# • The second a random number from 1 to 3
# • The third a random number from 10,000 to 30,000
pd1 = pd.Series(np.random.randint(1,5,size=(100)))

pd2 = pd.Series(np.random.randint(1,4,size=(100)))

pd3 = pd.Series(np.random.randint(10000,30001,size=(100)))

# %%
# Step 3. Create a DataFrame by joinning the Series by column
df =  pd.concat([pd1,pd2,pd3], axis=1)
df
# Out:
#     0  1      2
# 0   1  2  26636
# 1   4  3  23452
# 2   2  1  17667
# 3   1  2  19603
# 4   2  3  24512
# .. .. ..    ...
# 95  3  2  18010
# 96  4  2  20222
# 97  1  2  16791
# 98  1  2  17084
# 99  4  3  18621
#
# [100 rows x 3 columns]

# %%
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
df.columns = ['bedrs','bathrs','price_sqr_meter']
df
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       1       2            26636
# 1       4       3            23452
# 2       2       1            17667
# 3       1       2            19603
# 4       2       3            24512
# ..    ...     ...              ...
# 95      3       2            18010
# 96      4       2            20222
# 97      1       2            16791
# 98      1       2            17084
# 99      4       3            18621
#
# [100 rows x 3 columns]

# %%
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
bigcolumn = pd.DataFrame()
bigcolumn['b'] = pd.concat([df['bedrs'],df['bathrs'],df['price_sqr_meter']])
bigcolumn
# Out:
#         b
# 0       1
# 1       4
# 2       2
# 3       1
# 4       2
# ..    ...
# 95  18010
# 96  20222
# 97  16791
# 98  17084
# 99  18621
#
# [300 rows x 1 columns]

# %% [markdown]
# #####  Step 6. Ops it seems it is going only until index 99. Is it true?
#
# Yes the index is only going from 0 to 99, this is because it uses the existing indexes from the pandas series.

# %%
# Step 7. Reindex the DataFrame so it goes from 0 to 299
bigcolumn.reset_index()
# Out:
#      index      b
# 0        0      1
# 1        1      4
# 2        2      2
# 3        3      1
# 4        4      2
# ..     ...    ...
# 295     95  18010
# 296     96  20222
# 297     97  16791
# 298     98  17084
# 299     99  18621
#
# [300 rows x 2 columns]

# %% [markdown]
# ### Question 4

# %%
## Step 1. Import the necessary libraries 
import pandas as pd
import numpy as np 
import datetime

# %%
## Step 2. Import the dataset from the attached file wind.txt
data = pd.read_csv('wind.txt', delimiter=r"\s+")
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %%
## Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.
data['date_time'] = pd.to_datetime(data[["Yr","Mo","Dy"]].astype(str).agg('-'.join, axis=1))

data.drop(data.iloc[:, 0:3], inplace=True, axis=1)

# %%
## Year 2061? Do we really have data from this year? Create a function to fix it and apply it.
pd.DatetimeIndex(data['date_time']).year.unique()
# Out:
# Int64Index([2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071,
#             1972, 1973, 1974, 1975, 1976, 1977, 1978],
#            dtype='int64', name='date_time')

# %%
def fix_century(date_time):
    if date_time.year > 1979:
        year=date_time.year-100 
    else:
        year = date_time.year
    return datetime.date(year,date_time.month,date_time.day)
data['date_time']=data['date_time'].apply(fix_century)
data
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# 0     15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83  12.58
# 1     14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79   9.67
# 2     18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50   7.67
# 3     10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83   5.88
# 4     13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92  10.34
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04  14.00
# 6570  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25  18.05
# 6571  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50  16.42
# 6572  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46  12.12
# 6573  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58  11.38
#
#         BEL    MAL   date_time
# 0     18.50  15.04  1961-01-01
# ...

# %%
## Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].
type(data['date_time'][0])
# Out:
# datetime.date

# %%
data=data.set_index('date_time')
data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# date_time
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# date_time
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %%
data.index = pd.to_datetime(data.index)
data.index
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='date_time', length=6574, freq=None)

# %%
## Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below.

data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
## Step 7. Compute how many non-missing values there are in total.

data.isnull().sum().sum()
# Out:
# 31

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
##  Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.

# %%
data.mean().mean()
# Out:
# 10.222465245951712

# %%
## Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
## A different set of numbers for each location.

loc_stats = pd.DataFrame()
loc_stats['min']=data.min()
loc_stats['max']=data.max()
loc_stats['mean']=data.mean()
loc_stats['std']=data.std()
loc_stats
# Out:
#       min    max       mean       std
# RPT  0.67  35.80  12.359979  5.618805
# VAL  0.21  33.37  10.640267  5.268695
# ROS  1.50  33.84  11.656396  5.007805
# KIL  0.00  28.46   6.298587  3.600942
# SHA  0.13  37.54  10.448923  4.933988
# BIR  0.00  26.16   7.085066  3.967735
# DUB  0.00  30.37   9.793006  4.978030
# CLA  0.00  31.08   8.486601  4.498299
# MUL  0.00  25.88   8.490257  4.165947
# CLO  0.04  28.21   8.696705  4.500488
# BEL  0.13  42.38  13.110668  5.829054
# MAL  0.67  42.54  15.603129  6.702178

# %%
## Step 10: Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
## A different set of numbers for each day.

day_stats = pd.DataFrame()
day_stats['min']=data.min(axis=1)
day_stats['max']=data.max(axis=1)
day_stats['mean']=data.mean(axis=1)
day_stats['std']=data.std(axis=1)
day_stats.head()
# Out:
#              min    max       mean       std
# date_time
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# 1961-01-06  4.42  13.21   8.240000  2.998063
# 1961-01-07  4.96  14.29  10.385000  3.072114
# 1961-01-08  5.91  16.62  10.487500  3.547237

# %%
## Step 11. Find the average windspeed in January for each location.
## Treat January 1961 and January 1962 both as January.

# data.set_index('Date',inplace=True)
jan_data = data[data.index.month == 1]
jan_data.mean()
# Out:
# RPT    14.831609
# VAL    12.885389
# ROS    13.276275
# KIL     7.152477
# SHA    11.644467
# BIR     8.030561
# DUB    11.788336
# CLA     9.486962
# MUL     9.511501
# CLO    10.024069
# BEL    14.527848
# MAL    18.041826
# dtype: float64

# %%
## Step 12 : Downsample the record to a yearly frequency for each location

data.groupby(data.index.to_period('A')).mean()
# Out:
#                  RPT        VAL        ROS       KIL        SHA       BIR  \
# date_time
# 1961       12.207588  10.207206  11.282853  6.846441  10.742735  7.617147
# 1962       12.274779  10.150856  11.714365  6.964337  10.692265  7.415331
# 1963       12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964       12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965       12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966       13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967       12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968       11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969       11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970       12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971       11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %%
## Step 13. Downsample the record to a monthly frequency for each location.
data.groupby(data.index.to_period('M')).mean()
# Out:
#                  RPT        VAL        ROS       KIL        SHA        BIR  \
# date_time
# 1961-01    14.506154  11.225385  12.960385  6.840000  10.509231   8.174231
# 1961-02    16.401923  15.037308  14.470000  9.242692  13.778077  10.884615
# 1961-03    10.660000  11.097407  10.420000  7.100741  10.265556   8.580000
# 1961-04    10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05    10.024643   8.495714  10.539286  5.992500   9.480357   6.633929
# ...              ...        ...        ...       ...        ...        ...
# 1978-08     9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09    10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10     9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11    16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12    16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %%
## Step 14: Downsample the record to a weekly frequency for each location.

data.groupby(data.index.to_period('W')).mean()
# Out:
#                              RPT        VAL        ROS        KIL        SHA  \
# date_time
# 1961-01-02/1961-01-08  12.316000  10.408000  10.050000   5.658000   8.506000
# 1961-01-09/1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429
# 1961-01-16/1961-01-22  12.100000   9.500000  11.681667   4.293333   8.966667
# 1961-01-23/1961-01-29  19.880000  14.846667  17.548333  11.916667  16.325000
# 1961-01-30/1961-02-05  16.827143  15.460000  12.618571   8.247143  13.361429
# ...                          ...        ...        ...        ...        ...
# 1978-11-27/1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714
# 1978-12-04/1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143
# 1978-12-11/1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143
# 1978-12-18/1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714
# 1978-12-25/1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000
#
# ...

# %%
## Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

new_df= data.groupby(data.index.to_period('W')).mean().apply(lambda x: [x.count(),x.min(),x.max(),x.mean(),x.std()])
new_df = new_df.rename( index={0: 'count',1: 'min',2: 'max',3: 'mean',4: 'std'})
new_df
# Out:
#               RPT         VAL         ROS         KIL         SHA         BIR  \
# count  939.000000  939.000000  939.000000  939.000000  939.000000  939.000000
# min      3.874286    2.452857    4.901429    1.447143    2.775714    1.382857
# max     24.010000   23.715714   21.384286   14.517143   22.897143   16.010000
# mean    12.356298   10.635444   11.652878    6.299636   10.449166    7.086745
# std      3.464961    3.371183    2.844036    2.182339    3.142446    2.552300
#
#               DUB         CLA         MUL         CLO         BEL         MAL
# count  939.000000  939.000000  939.000000  939.000000  939.000000  939.000000
# min      2.471429    2.284286    2.262857    1.571429    3.661429    5.124286
# max     20.474286   17.861429   17.460000   17.932857   26.617143   30.374286
# mean     9.792288    8.486521    8.490357    8.699941   13.110130   15.593725
# std      3.310785    2.851360    2.636005    2.918842    3.746798    4.472537

# %% [markdown]
# #### Question 5

# %%
## Step 1. Import the necessary libraries
import pandas as pd 
import numpy as np

# %%
## Step 2. Import the dataset from this address.
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t',)
## Step 3. Assign it to a variable called chipo.
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
## Step 4. See the first 10 entries
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
## Step 5. What is the number of observations in the dataset?
chipo.shape[0]
# Out:
# 4622

# %%
## Step 6. What is the number of columns in the dataset?
chipo.shape[1]
# Out:
# 5

# %%
## Step 7. Print the name of all the columns.
print(chipo.columns.values)
# Out:
# ['order_id' 'quantity' 'item_name' 'choice_description' 'item_price']

# %%
## Step 8. How is the dataset indexed?
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
## Step 9. Which was the most-ordered item? 
totals_order_item = chipo.groupby(['item_name'])[['quantity','item_name']].sum() 
totals_order_item
# Out:
#                                        quantity
# item_name
# 6 Pack Soft Drink                            55
# Barbacoa Bowl                                66
# Barbacoa Burrito                             91
# Barbacoa Crispy Tacos                        12
# Barbacoa Salad Bowl                          10
# Barbacoa Soft Tacos                          25
# Bottled Water                               211
# Bowl                                          4
# Burrito                                       6
# Canned Soda                                 126
# Canned Soft Drink                           351
# Carnitas Bowl                                71
# Carnitas Burrito                             60
# Carnitas Crispy Tacos                         8
# Carnitas Salad                                1
# Carnitas Salad Bowl                           6
# Carnitas Soft Tacos                          40
# Chicken Bowl                                761
# ...

# %%
## Step 10. For the most-ordered item, how many items were ordered?
totals_order_item.idxmax()
# Out:
# quantity    Chicken Bowl
# dtype: object

# %%
totals_order_item.max()
# Out:
# quantity    761
# dtype: int64

# %%
## Step 11 : What was the most ordered item in the choice_description column?
chipo['choice_description'].value_counts().head(1)
# Out:
# [Diet Coke]    134
# Name: choice_description, dtype: int64

# %%
## Step 12. How many items were orderd in total?

chipo['quantity'].sum()
# Out:
# 4972

# %%
## Step 13. • Turn the item price into a float
chipo['item_price'] = chipo['item_price'].apply(lambda price: float(price[1:-1]))
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
## Step 14 How much was the revenue for the period in the dataset?

chipo['item_price'].sum()
# Out:
# 34500.16

# %%
chipo['order_id'].value_counts().sum()
# Out:
# 4622

# %%
# Step 16. What is the average revenue amount per order?
chipo.groupby(['order_id'])['item_price'].sum().mean()
# Out:
# 18.81142857142869

# %%
## Step 17. How many different items are sold?
chipo['item_name'].nunique()
# Out:
# 50

# %% [markdown]
# ### Question 6
# Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
us_marriages = pd.read_csv('us-marriages-divorces-1867-2014.csv')

# %%
us_marriages
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0    1867   357000.0   10000.0    36970000                 9.7
# 1    1868   345000.0   10000.0    37885000                 9.1
# 2    1869   348000.0   11000.0    38870000                 9.0
# 3    1870   352000.0   11000.0    39905000                 8.8
# 4    1871   359000.0   12000.0    41010000                 8.8
# ..    ...        ...       ...         ...                 ...
# 140  2007  2197000.0  856000.0   301696000                 7.3
# 141  2008  2157000.0  844000.0   304543000                 7.1
# 142  2009  2080000.0  840000.0   307240000                 6.8
# 143  2010  2096000.0  872000.0   309776000                 6.8
# 144  2011  2118000.0  877000.0   312034000                 6.8
#
#      Divorces_per_1000
# 0                  0.3
# 1                  0.3
# 2                  0.3
# 3                  0.3
# 4                  0.3
# ..                 ...
# 140                2.8
# ...

# %%
plt.figure()
plt.title("Marriages/Divorces in US across the years")
plt.plot(us_marriages['Year'], us_marriages['Marriages_per_1000'], label = "line 1")
plt.plot(us_marriages['Year'], us_marriages['Divorces_per_1000'], label = "line 2")
plt.xlabel("Year")
plt.ylabel("Marriages/Divorces per 1000 capita")
plt.legend()
plt.show()

# %% [markdown]
# ### Question 7
# Create a vertical bar chart comparing the number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000.

# %%
import pandas as pd
import numpy as nm
import matplotlib.pyplot as mp

us_marriages = pd.read_csv('us-marriages-divorces-1867-2014.csv')

us_marriages = us_marriages.loc[us_marriages['Year'].isin([1900,1950,2000])]

# %%
marriage_per_capita = us_marriages['Marriages_per_1000']
marriage_per_capita = marriage_per_capita.values
divorce_per_capita = us_marriages['Divorces_per_1000']
divorce_per_capita = divorce_per_capita.values
year = us_marriages['Year']

df = pd.DataFrame({'Marriages_Per_Capita':marriage_per_capita, 'Divorces_Per_Capita':divorce_per_capita}, index=year)

df.plot.bar()

mp.xlabel("Year")

mp.ylabel("Marriages/Divorces Per Capita")

mp.legend(["Marriages Per Capita", "Divorces Per Capita"])

mp.show()

# %% [markdown]
# ### Question 8
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort the actors by their kill count and label each bar with the corresponding actor's name.

# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
hollywood_data = pd.read_csv('actor_kill_counts.csv')
hollywood_data
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 7     Sylvester Stallone    267
# 8    Tomisaburo Wakayama    226
# 9          Wesley Snipes    193

# %%
plot_order = hollywood_data.sort_values(by='Count', ascending=False)
plot_order
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 7     Sylvester Stallone    267
# 4         Dolph Lundgren    239
# 8    Tomisaburo Wakayama    226
# 2         Clint Eastwood    207
# 6           Nicolas Cage    204
# 5                 Jet Li    201
# 3             Clive Owen    194
# 9          Wesley Snipes    193

# %%
sns.barplot(data = plot_order,x= 'Count', y= 'Actor',orient='h').set(title='Deadliest Actors in Hollywood')
# Out:
# [Text(0.5, 1.0, 'Deadliest Actors in Hollywood')]

# %% [markdown]
# ### Question 9
#
# Create a pie chart showing the fraction of all Roman Emperors that were assassinated.

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
roman_deaths = pd.read_csv('roman-emperor-reigns.csv')
roman_deaths
# Out:
#            Emperor  Length_of_Reign         Cause_of_Death
# 0         Augustus            40.58  Possibly assassinated
# 1         Tiberius            22.50  Possibly assassinated
# 2         Caligula             4.83           Assassinated
# 3         Claudius            13.75  Possibly assassinated
# 4             Nero            13.67                Suicide
# ..             ...              ...                    ...
# 63   Valentinian I            11.00         Natural causes
# 64          Valens            14.00       Killed in battle
# 65         Gratian            16.00           Assassinated
# 66  Valentinian II            17.00  Possibly assassinated
# 67    Theodosius I            16.00         Natural causes
#
# [68 rows x 3 columns]

# %%
test = roman_deaths.groupby(['Cause_of_Death']).count()['Emperor']

# %%
# %matplotlib inline
sns.set()
test.plot.pie(autopct="%.1f%%", figsize = (8,8) , fontsize = 15, ylabel = '', explode=[0.01]*8)
plt.title("Roman Emperor's Cause of Death", color = 'Black', fontsize = 18)
# Out:
# Text(0.5, 1.0, "Roman Emperor's Cause of Death")

# %% [markdown]
# ### Question 10
# Create a scatter plot showing the relationship between the total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
df
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
# 5  2005                            1.435
# 6  2006                            1.601
# 7  2007                            1.654
# 8  2008                            1.803
# 9  2009                            1.734
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948
# 5                                      1129
# 6                                      1453
# 7                                      1656
# 8                                      1787
# 9                                      1611

# %%
plt.scatter(x="Total Arcade Revenue (billions)",y="Computer Science Doctorates Awarded (US)",c=df.Year,data=df)
plt.xlabel('Total Arcade Revenue (billions)')
plt.ylabel('Computer Science Doctorates Awarded (US)')
plt.title('Total Arcade Revenue (billions) vs Computer Science Doctorates Awarded (US) ')
plt.colorbar()
plt.show()
# Out:
# C:\Users\ruwin\AppData\Local\Temp\ipykernel_26128\4172107449.py:5: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()
